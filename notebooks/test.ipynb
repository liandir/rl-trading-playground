# %%
import sys
sys.path.append("..")

from src.sim import demo_rollout
from src.viz import make_bokeh_plot

# %%
V_hist, w_hist, p_hist, C_hist = demo_rollout(T=250, N=4, seed=42, mu=0.03, sigma=0.3)

# %%
from bokeh.plotting import output_notebook
output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ff3d4651-89af-412f-9e28-9e49cb2b27a0">Loading BokehJS ...</span>
#     </div>

# %%
make_bokeh_plot(V_hist, w_hist, p_hist, C_hist, title="Multi-Currency Env Demo")
# Out:
#   <div id="ef07d4d7-5c95-4659-9644-ff7fbad48a9f" data-root-id="p1239" style="display: contents;"></div>
